# %%
import datetime
myNow = datetime.datetime.now()
print('Date and time is: ', myNow)
# Out:
# Date and time is:  2021-09-26 10:17:23.343048

# %%
myNumber = 10
myText = "hello"
print(myNumber,myText)
# Out:
# 10 hello

# %%
print(type(myNumber), type(myText), type(myNow))
# Out:
# <class 'int'> <class 'str'> <class 'datetime.datetime'>

# %%
#Lists
studentsGrades = [1,3.5,6]
help(str.upper)
#dir(__builtins__)
# Out:
# Help on method_descriptor:
#
# upper(self, /)
#     Return a copy of the string converted to uppercase.

# %%
sumOfnumbers = sum(studentsGrades)
length = len(studentsGrades)
avg = sumOfnumbers/length
print(avg)
# Out:
# 3.5

# %%
#Dictionary
studentGrades = {"Mary": 9, "John": 10, "Limkin": 8}
print((studentGrades.values()))
print(studentGrades.keys())
# Out:
# dict_values([9, 10, 8])
# dict_keys(['Mary', 'John', 'Limkin'])
